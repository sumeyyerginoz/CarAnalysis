# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("merc.xlsx")
df=data.copy()

# %% [markdown]
# # Veri Anlamlandırma

# %%
df.shape
# Out:
# (13119, 7)

# %%
df.columns
# Out:
# Index(['year', 'price', 'transmission', 'mileage', 'tax', 'mpg', 'engineSize'], dtype='object')

# %%
df.rename(columns={'year':"yıl", 'price':"fiyat", 'transmission':"vites", 'mileage':"kilometre", 'tax':"vergi", 'mpg':"km_basina_yakıtüketimi", 'engineSize':"motorhacmi"}, inplace=True)

# %%
df.columns
# Out:
# Index(['yıl', 'fiyat', 'vites', 'kilometre', 'vergi', 'km_basina_yakıtüketimi',
#        'motorhacmi'],
#       dtype='object')

# %%
df.head(10)
# Out:
#     yıl   fiyat      vites  kilometre  vergi  km_basina_yakıtüketimi  \
# 0  2005    5200  Automatic      63000    325                    32.1
# 1  2017   34948  Automatic      27000     20                    61.4
# 2  2016   49948  Automatic       6200    555                    28.0
# 3  2016   61948  Automatic      16000    325                    30.4
# 4  2016   73948  Automatic       4000    325                    30.1
# 5  2011  149948  Automatic       3000    570                    21.4
# 6  2018   30948  Automatic      16000    145                    47.9
# 7  2012   10948  Automatic     107000    265                    36.7
# 8  2019  139948  Automatic      12000    145                    21.4
# 9  2017   19750  Automatic      15258     30                    64.2
#
#    motorhacmi
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0
# 5         6.2
# 6         2.1
# 7         3.5
# 8         4.0
# 9         2.1

# %%
df.tail()
# Out:
#         yıl  fiyat      vites  kilometre  vergi  km_basina_yakıtüketimi  \
# 13114  2020  35999  Automatic        500    145                    55.4
# 13115  2020  24699  Automatic       2500    145                    55.4
# 13116  2019  30999  Automatic      11612    145                    41.5
# 13117  2019  37990  Automatic       2426    145                    45.6
# 13118  2019  54999  Automatic       2075    145                    52.3
#
#        motorhacmi
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13119 entries, 0 to 13118
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   yıl                     13119 non-null  int64
#  1   fiyat                   13119 non-null  int64
#  2   vites                   13119 non-null  object
#  3   kilometre               13119 non-null  int64
#  4   vergi                   13119 non-null  int64
#  5   km_basina_yakıtüketimi  13119 non-null  float64
#  6   motorhacmi              13119 non-null  float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 717.6+ KB

# %%
df.isnull()
# Out:
#          yıl  fiyat  vites  kilometre  vergi  km_basina_yakıtüketimi  \
# 0      False  False  False      False  False                   False
# 1      False  False  False      False  False                   False
# 2      False  False  False      False  False                   False
# 3      False  False  False      False  False                   False
# 4      False  False  False      False  False                   False
# ...      ...    ...    ...        ...    ...                     ...
# 13114  False  False  False      False  False                   False
# 13115  False  False  False      False  False                   False
# 13116  False  False  False      False  False                   False
# 13117  False  False  False      False  False                   False
# 13118  False  False  False      False  False                   False
#
#        motorhacmi
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# ...

# %%
df.isnull().sum()
# Out:
# yıl                       0
# fiyat                     0
# vites                     0
# kilometre                 0
# vergi                     0
# km_basina_yakıtüketimi    0
# motorhacmi                0
# dtype: int64

# %%
pd.DataFrame(df["yıl"].unique())
# Out:
#        0
# 0   2005
# 1   2017
# 2   2016
# 3   2011
# 4   2018
# 5   2012
# 6   2019
# 7   2020
# 8   2014
# 9   2015
# 10  2006
# 11  2010
# 12  2004
# 13  2008
# 14  2013
# 15  2007
# 16  2009
# 17  2003
# 18  2001
# 19  2002
# 20  1998
# 21  2000
# 22  1997
# 23  1999
# 24  1970

# %%
pd.DataFrame(df["fiyat"].unique())
# Out:
#           0
# 0      5200
# 1     34948
# 2     49948
# 3     61948
# 4     73948
# ...     ...
# 4419  38343
# 4420  30045
# 4421  34459
# 4422  25829
# 4423  19344
#
# [4424 rows x 1 columns]

# %%
df.describe()
# Out:
#                 yıl          fiyat      kilometre         vergi  \
# count  13119.000000   13119.000000   13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178
# std        2.224709   11842.675542   21176.512267     65.260286
# min     1970.000000     650.000000       1.000000      0.000000
# 25%     2016.000000   17450.000000    6097.500000    125.000000
# 50%     2018.000000   22480.000000   15189.000000    145.000000
# 75%     2019.000000   28980.000000   31779.500000    145.000000
# max     2020.000000  159999.000000  259000.000000    580.000000
#
#        km_basina_yakıtüketimi    motorhacmi
# count            13119.000000  13119.000000
# mean                55.155843      2.071530
# std                 15.220082      0.572426
# min                  1.100000      0.000000
# 25%                 45.600000      1.800000
# 50%                 56.500000      2.000000
# 75%                 64.200000      2.100000
# ...

# %%
df.describe(include=["object"]) # kategorik verilerin istatiksel bilgilerini veriyor.
# Out:
#             vites
# count       13119
# unique          4
# top     Semi-Auto
# freq         6848

# %%
pd.DataFrame(df["vites"].unique())
# Out:
#            0
# 0  Automatic
# 1     Manual
# 2  Semi-Auto
# 3      Other

# %% [markdown]
# # Veri Görselleştirme

# %%
def pie_chart(dataframe, columns):
    dataframe[columns].value_counts().plot.pie()    
    plt.legend(title=columns)
    plt.show()

# %%
pie_chart(df,"vites")

# %%
pie_chart(df,"motorhacmi")

# %%
sns.lineplot(data=df,x="fiyat",y="yıl")
# Out:
# <AxesSubplot:xlabel='fiyat', ylabel='yıl'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(df["yıl"])
# Out:
# /Users/sumeyye/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='yıl', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x="yıl",y="fiyat",data=df,)
# Out:
# <AxesSubplot:xlabel='yıl', ylabel='fiyat'>

# %%
sns.countplot(x=df["vites"])
# Out:
# <AxesSubplot:xlabel='vites', ylabel='count'>

# %%
df.sort_values("fiyat",ascending = False).head(20) # ascending = False -> büüyükten küçüğe
# Out:
#         yıl   fiyat      vites  kilometre  vergi  km_basina_yakıtüketimi  \
# 6199   2020  159999  Semi-Auto       1350    145                    21.4
# 10044  2020  154998  Automatic       3000    150                    21.4
# 5      2011  149948  Automatic       3000    570                    21.4
# 8737   2019  140319  Semi-Auto        785    150                    22.1
# 6386   2018  139995  Semi-Auto      13046    145                    21.4
# 8      2019  139948  Automatic      12000    145                    21.4
# 9133   2019  139559  Semi-Auto       1000    145                    22.1
# 8821   2020  138439  Semi-Auto       1000    145                    22.1
# 5902   2018  135771  Semi-Auto      19000    145                    21.4
# 7864   2018  135124  Semi-Auto      18234    150                    21.4
# 8673   2019  134219  Semi-Auto       1000    145                    24.8
# 6210   2019  129990  Automatic       1000    145                    24.8
# ...

# %%
manuel=df[(df.vites == "Manual")]

# %%
manuel.sort_values("fiyat",ascending = False).head(20) # ascending = False -> büüyükten küçüğe
#manuel araçların fiyatının yüksek olmadığını kanıtladık
# Out:
#         yıl  fiyat   vites  kilometre  vergi  km_basina_yakıtüketimi  \
# 1520   2016  36999  Manual      20455    200                    46.3
# 7915   2020  29495  Manual        500    145                    37.2
# 170    2019  28998  Manual         22    145                    48.7
# 6206   2020  28989  Manual       3150    145                    45.6
# 5868   2020  28200  Manual       1932    145                    28.5
# 5081   2020  27987  Manual       2369    145                    44.1
# 5869   2020  27720  Manual         10    145                    28.5
# 1948   2020  26995  Manual       5000    145                    47.1
# 3917   2019  26991  Manual       1998    150                    47.1
# 4620   2020  26990  Manual       1499    145                    47.1
# 11946  2017  26990  Manual       6000    260                    37.2
# 2976   2020  26980  Manual         16    145                    44.1
# 2975   2020  26980  Manual         16    145                    44.8
# ...

# %%
sns.scatterplot(x="kilometre",y="fiyat",data=df)
# Out:
# <AxesSubplot:xlabel='kilometre', ylabel='fiyat'>

# %%
sns.jointplot(y = 'fiyat',x = 'kilometre', data = df,)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/bg/7kqfw1hj6llfv4z2gzk8mqhr0000gn/T/ipykernel_1337/188289125.py in <module>
# ----> 1 sns.jointplot(y = 'fiyat',x = 'kilometre', data = df,)
#
# NameError: name 'sns' is not defined

# %%
sns.scatterplot(x="kilometre",y="yıl",data=df)
# Out:
# <AxesSubplot:xlabel='kilometre', ylabel='yıl'>

# %%
sns.pairplot(df)

# %% [markdown]
# # Değerler arasındaki ilişki ( Korelasyon )

# %%
df.corr()
# Out:
#                              yıl     fiyat  kilometre     vergi  \
# yıl                     1.000000  0.520712  -0.738027  0.012480
# fiyat                   0.520712  1.000000  -0.537214  0.268717
# kilometre              -0.738027 -0.537214   1.000000 -0.160223
# vergi                   0.012480  0.268717  -0.160223  1.000000
# km_basina_yakıtüketimi -0.094626 -0.438445   0.202850 -0.513742
# motorhacmi             -0.142147  0.516126   0.063652  0.338341
#
#                         km_basina_yakıtüketimi  motorhacmi
# yıl                                  -0.094626   -0.142147
# fiyat                                -0.438445    0.516126
# kilometre                             0.202850    0.063652
# vergi                                -0.513742    0.338341
# km_basina_yakıtüketimi                1.000000   -0.339862
# motorhacmi                           -0.339862    1.000000

# %%
df.corr()["fiyat"].sort_values()
# Out:
# kilometre                -0.537214
# km_basina_yakıtüketimi   -0.438445
# vergi                     0.268717
# motorhacmi                0.516126
# yıl                       0.520712
# fiyat                     1.000000
# Name: fiyat, dtype: float64

# %%
sns.heatmap(df.corr(),annot=True,vmin=-1,vmax=1)
# Out:
# <AxesSubplot:>

# %%
sns.clustermap(df.corr(),annot=True,vmin=-1,vmax=1,linewidths=1,)

# %% [markdown]
# # aykırı değerler

# %%
sns.distplot(df["fiyat"])
# Out:
# /Users/sumeyye/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fiyat', ylabel='Density'>

# %%
sns.boxplot(df["fiyat"])
# Out:
# /Users/sumeyye/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fiyat'>

# %% [markdown]
# ## silme

# %% [markdown]
# Eğer veri setimizde aykırı değerler varsa, bu durumda veriyi temizlemek için silme işlemini kullanmaya karar verebiliriz. Ancak, genellikle en fazla %1'lik bir kısmın silinmesi önerilir çünkü veri setindeki çok sayıda veri kaybı analiz sonuçlarını bozabilir. Bu nedenle, verimizi bozmadan anlamlı sonuçlar elde etmek için mümkün olduğunca az sayıda veri silmeye çalışmalıyız.

# %%
len(df)
# Out:
# 13119

# %%
len(df) * 0.01
# Out:
# 131.19

# %%
df = df.sort_values("fiyat",ascending = False).iloc[131:]

# %%
df
# Out:
#         yıl  fiyat      vites  kilometre  vergi  km_basina_yakıtüketimi  \
# 6177   2019  65990  Semi-Auto       5076    150                    30.4
# 5779   2020  65990  Semi-Auto        999    145                    28.0
# 3191   2020  65980  Semi-Auto       3999    145                    28.0
# 4727   2019  65000  Semi-Auto       3398    145                    27.2
# 8814   2019  64999  Semi-Auto        119    145                    40.9
# ...     ...    ...        ...        ...    ...                     ...
# 11549  2002   1495  Automatic      13800    305                    39.8
# 12594  2004   1495     Manual     119000    300                    34.5
# 11765  2000   1490  Automatic      87000    265                    27.2
# 12008  2010   1350     Manual     116126    145                    54.3
# 11816  2003    650     Manual     109090    235                    40.0
#
#        motorhacmi
# 6177          3.0
# 5779          4.0
# 3191          4.0
# 4727          4.0
# ...

# %%
df.sort_values("fiyat",ascending = False).head(20)
# Out:
#         yıl  fiyat      vites  kilometre  vergi  km_basina_yakıtüketimi  \
# 6177   2019  65990  Semi-Auto       5076    150                    30.4
# 5779   2020  65990  Semi-Auto        999    145                    28.0
# 3191   2020  65980  Semi-Auto       3999    145                    28.0
# 4727   2019  65000  Semi-Auto       3398    145                    27.2
# 8814   2019  64999  Semi-Auto        119    145                    40.9
# 8083   2018  64999  Semi-Auto      41102    145                    23.0
# 267    2019  64998  Semi-Auto        313    145                    31.4
# 2956   2020  64980  Semi-Auto       3999    145                    40.4
# 2274   2020  64980  Semi-Auto       3999    145                    40.4
# 12160  2018  64950  Automatic      13000    145                    28.5
# 8869   2020  64359  Semi-Auto       1000    145                    29.5
# 6218   2019  63999  Automatic        618    145                    52.3
# ...

# %%
plt.figure(figsize=(7,5))
sns.distplot(df["fiyat"])
# Out:
# /Users/sumeyye/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fiyat', ylabel='Density'>

# %%
sns.boxplot(df["fiyat"])
# Out:
# /Users/sumeyye/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fiyat'>

# %%
df.describe()
# Out:
#                 yıl         fiyat      kilometre         vergi  \
# count  12988.000000  12988.000000   12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714
# std        2.228515   9866.224575   21196.776401     65.183076
# min     1970.000000    650.000000       1.000000      0.000000
# 25%     2016.000000  17357.500000    6322.000000    125.000000
# 50%     2018.000000  22299.000000   15369.500000    145.000000
# 75%     2019.000000  28706.000000   31982.250000    145.000000
# max     2020.000000  65990.000000  259000.000000    580.000000
#
#        km_basina_yakıtüketimi    motorhacmi
# count            12988.000000  12988.000000
# mean                55.437142      2.050901
# std                 15.025999      0.532596
# min                  1.100000      0.000000
# 25%                 45.600000      1.675000
# 50%                 56.500000      2.000000
# 75%                 64.200000      2.100000
# ...

# %%
df.groupby("yıl").mean()["fiyat"]
# Out:
# yıl
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: fiyat, dtype: float64

# %%
df[df.yıl < 2014].groupby("yıl").mean()["fiyat"]
# Out:
# yıl
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# Name: fiyat, dtype: float64

# %% [markdown]
# ## yaklaşık değere çekme

# %%
def outlier_thresholds(dataframe, col_name, q1=0.05, q3=0.95):
    q1 = dataframe[col_name].quantile(q1)  # 1.Çeyrek
    q3 = dataframe[col_name].quantile(q3)  # 3.Çeyrek
    interquantile_range = q3 - q1  # range'i hesaplayalım
    low_limit = q1 - 1.5 * interquantile_range # low & up limit:
    up_limit = q3 + 1.5 * interquantile_range
    return low_limit, up_limit

# %%
# Outlier Değer Var mı Yok Mu:
def check_outlier(dataframe, col_name):
    low_limit, up_limit = outlier_thresholds(dataframe, col_name)
    if dataframe[(dataframe[col_name] > up_limit) | (dataframe[col_name] < low_limit)].any(axis=None):
        return True
    else:
        return False

# %%
# Outlier Değerlere Erişmek:
def grab_outliers(dataframe, col_name, index=False):
    low_limit, up_limit = outlier_thresholds(dataframe, col_name)
    if dataframe[(dataframe[col_name] < low_limit) | (dataframe[col_name] > up_limit)].shape[0] > 10:
        print(dataframe[(dataframe[col_name] < low_limit) | (dataframe[col_name] > up_limit)].head())
    else:
        print(dataframe[(dataframe[col_name] < low_limit) | (dataframe[col_name] > up_limit)])
    if index:
        outlier_index = dataframe[(dataframe[col_name] < low_limit) | (dataframe[col_name] > up_limit)].index
        return outlier_index

# %%
outlier_thresholds(df,"fiyat")
# Out:
# (-37657.14999999999, 93685.64999999998)

# %%
check_outlier(df,"fiyat")
# Out:
# False

# %%
grab_outliers(df,"fiyat")
# Out:
# Empty DataFrame
# Columns: [yıl, fiyat, vites, kilometre, vergi, km_basina_yakıtüketimi, motorhacmi]
# Index: []

# %%
sns.boxplot(df["fiyat"])
# Out:
# /Users/sumeyye/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fiyat'>

# %%
# Silme ile remove_outlierçözümleme:
def remove_outlier (dataframe, col_name, q1=0.1, q3=0.90):
    low_limit, up_limit = outlier_thresholds(dataframe, col_name, q1, q3)
    df_without_outliers = dataframe[~((dataframe[col_name] < low_limit) | (dataframe[col_name] > up_limit))]
    return df_without_outliers

# %%
clear_df=remove_outlier(df,"fiyat")

# %%
clear_df.shape
# Out:
# (12988, 7)

# %%
sns.boxplot(clear_df["fiyat"])
# Out:
# /Users/sumeyye/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fiyat'>

# %%
# Baskılama yöntemi:
def replace_with_thresholds(dataframe, variable, q1=0.1, q3=0.90):
    low_limit, up_limit = outlier_thresholds(dataframe, variable, q1, q3)
    dataframe.loc[(dataframe[variable] > up_limit), variable] = up_limit
    dataframe.loc[(dataframe[variable] < low_limit), variable] = low_limit

# %%
replace_with_thresholds(df,"fiyat")

# %%
sns.boxplot(df["fiyat"])
# Out:
# /Users/sumeyye/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fiyat'>
